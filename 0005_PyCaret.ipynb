# %% [markdown]
# # PyCaret

# %% [markdown]
# ## Imports and data loading

# %%
from pycaret.classification import * 
from pycaret.datasets import get_data

diabetes = get_data('diabetes')
exp_clf = setup(diabetes, target='Class variable')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_38efb7ea_bddb_11ea_9ce1_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row0_col1" class="data row0 col1" >2895</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row3_col1" class="data row3 col1" >(768, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row5_col1" class="data row5 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row6_col1" class="data row6 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row10_col1" class="data row10 col1" >(768, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row11_col1" class="data row11 col1" >(537, 24)</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row12_col1" class="data row12 col1" >(231, 24)</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_38efb7ea_bddb_11ea_9ce1_acde48001122level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_38efb7ea_bddb_11ea_9ce1_acde48001122row18_col1" class="data row18 col1" >None</td>
#             </tr>
#             <

# %% [markdown]
# <br><br>
#
# ## Finding optimal model

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_5a9d4d58_bddb_11ea_9ce1_acde48001122 th {
#           text-align: left;
#     }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row0_col0 {
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row1_col0 {
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row1_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row1_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row1_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row1_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row2_col0 {
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row3_col0 {
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row4_col0 {
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row5_col0 {
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row6_col0 {
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row7_col0 {
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row8_col0 {
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row8_col4 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row9_col0 {
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row9_col4 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row10_col0 {
#             text-align:  left;
#         }    #T_5a9d4d58_bddb_11ea_9ce1_acde48001122row10

# %%
xgb = create_model('xgboost')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7778  0.8466  0.7368  0.6667  0.7000  0.5242
# 1       0.6852  0.7368  0.3684  0.5833  0.4516  0.2463
# 2       0.7778  0.8090  0.5789  0.7333  0.6471  0.4882
# 3       0.7037  0.7789  0.5789  0.5789  0.5789  0.3504
# 4       0.7963  0.8962  0.6842  0.7222  0.7027  0.5479
# 5       0.6852  0.7429  0.4211  0.5714  0.4848  0.2656
# 6       0.7778  0.8195  0.5789  0.7333  0.6471  0.4882
# 7       0.7925  0.8413  0.6667  0.7059  0.6857  0.5310
# 8       0.8302  0.8698  0.7778  0.7368  0.7568  0.6265
# 9       0.7736  0.8984  0.7778  0.6364  0.7000  0.5211
# Mean    0.7600  0.8240  0.6170  0.6668  0.6355  0.4589
# SD      0.0477  0.0549  0.1333  0.0656  0.0949  0.1206

# %% [markdown]
# ## Visualizing model performance

# %%
plot_model(xgb)

# %%
plot_model(xgb, 'confusion_matrix')

# %%
plot_model(xgb, 'class_report')

# %% [markdown]
# <br><br>
#
# ## Model interpretation with SHAP

# %%
interpret_model(xgb)

# %% [markdown]
# <br><br>
#
# ## Predictions

# %%
predictions = predict_model(xgb)
# Out:
#                        Model  Accuracy    AUC  Recall   Prec.      F1   Kappa
# 0  Extreme Gradient Boosting    0.7792  0.839  0.6543  0.6974  0.6752  0.5082

# %% [markdown]
# <br><br>
#
# ## Model saving and loading

# %%
finalize_model(xgb)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=-1,
#               nthread=None, objective='binary:logistic', random_state=2895,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=0)

# %%
save_model(xgb, 'diabetes_xgboost')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
model = load_model('diabetes_xgboost')
# Out:
# Transformation Pipeline and Model Sucessfully Loaded

# %% [markdown]
# <br><br>
#
# ## Model deployment

# %%
deploy_model(
    model, 
    model_name='xgboost_aws', 
    platform='aws', 
    authentication={'bucket': 'pycaret-test'}
)
